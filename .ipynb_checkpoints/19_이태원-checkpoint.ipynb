# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use('default')

# %%
df = pd.read_csv("e:/Vacancy_arima2.csv", encoding= 'ansi')

# %%
df.head()
# Out:
#          Date  Rent_pred
# 0  2015-03-01     13.058
# 1  2015-06-01     12.153
# 2  2015-09-01     12.087
# 3  2015-12-01     10.335
# 4  2016-03-01     12.260

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df = df.set_index(df['Date'])
df = df.iloc[:, 1]
df.head()
# Out:
# Date
# 2015-03-01    13.058
# 2015-06-01    12.153
# 2015-09-01    12.087
# 2015-12-01    10.335
# 2016-03-01    12.260
# Name: Rent_pred, dtype: float64

# %%
df.plot()

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
m = ARIMA(df, [0,1,1])
r = m.fit()
print(r.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:            D.Rent_pred   No. Observations:                   15
# Model:                 ARIMA(0, 1, 1)   Log Likelihood                 -36.347
# Method:                       css-mle   S.D. of innovations              2.724
# Date:                Tue, 08 Oct 2019   AIC                             78.694
# Time:                        17:46:01   BIC                             80.818
# Sample:                    06-01-2015   HQIC                            78.671
#                          - 12-01-2018
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 0.9635      0.539      1.788      0.097      -0.092       2.019
# ma.L1.D.Rent_pred    -0.2559      0.223     -1.148      0.272      -0.693       0.181
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1            3.9084           +0.0000j            3.9084            0.0000
# -----------------------------------------------------------------------------
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency QS-DEC will be used.
#   % freq, ValueWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency QS-DEC will be used.
#   % freq, ValueWarning)

# %%
r.forecast(steps= 1)
# Out:
# (array([27.88428118]),
#  array([2.72356574]),
#  array([[22.54619042, 33.22237194]]))

# %%
r.plot_predict(end=20, plot_insample=False)
